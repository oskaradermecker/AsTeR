# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from process.paths import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\meryl\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['griddata', 'datetime', 'arrow']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [raw]
# CityGraph('maps/butte_roads.shp').build_graph(dump='maps/butte_graph.jb')

# %%
trg = Trajectory('maps/butte_graph.jb')
u,v = np.random.choice(list(trg.G.keys()), 2)
trg.visual_path(u, v, [39.5, -121.5], zoom=9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
view = folium.Map(location=[39.759132, -121.619311], zoom_start=11)

wea = Weather('maps/paradise_weather_grid.npy')
dtf = wea.aggregate(datetime(year=2018, month=11, day=1))

arrow = wea.wind_arrows(dtf)
arrow.add_to(view)
group = wea.contour_plot(dtf, 'windSpeed')
group.add_to(view)

view
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 73/73 [00:29<00:00,  2.47it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dtf.to_pickle('maps/weather_20181101.df')
